3'], ['perovskite', 'nanbo3'], ['perovskite', 'nanbo3'], ['perovskite', 'nasbo3'], ['perovskite', 'natao3'], ['perovskite', 'navo3'], ['spinel', 'nial2o4'], ['spinel', 'nife2o4'], ['spinel', 'nini2o4'], ['perovskite', 'sralo3'], ['perovskite', 'srcoo3'], ['perovskite', 'srfeo3'], ['perovskite', 'srmn3po3'], ['perovskite', 'srsno3'], ['perovskite', 'yalo3'], ['perovskite', 'ygao3'], ['perovskite', 'snfeo3'], ['perovskite', 'snfeo3'], ['perovskite', 'sralo3'], ['perovskite', 'srfeo3'], ['perovskite', 'srmn3po3'], ['perovskite', 'srsno3'], ['perovskite', 'yalo3'], ['perovskite', 'ygao3'], ['perovskite', 'scalo3'], ['perovskite', 'sncoo3'], ['perovskite', 'sncro3'], ['perovskite', 'snhfo3'], ['perovskite', 'snmno3'], ['perovskite', 'snnio3'], ['perovskite', 'snseo3'], ['perovskite', 'snsio3'], ['perovskite', 'sntao3'], ['perovskite', 'sntio3'], ['perovskite', 'snvo3'], ['perovskite', 'snzro3'], ['perovskite', 'srgeo3'], ['perovskite', 'srhfo3'], ['perovskite', 'srmno3'], ['perovskite', 'srseo3'], ['perovskite', 'srtio3'], ['perovskite', 'srvo3'], ['perovskite', 'srzro3'], ['perovskite', 'tiseo3'], ['perovskite', 'tisio3'], ['perovskite', 'ycro3'], ['perovskite', 'ynio3'], ['perovskite', 'ytao3'], ['perovskite', 'yvo3'], ['pero ...
# Multiple Matches {'material': ['spinel', 'alv2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['spinel', 'alv2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bacoo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bacoo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bialo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bicoo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.5', 'material': ['perovskite', 'bicro3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bicuo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.6', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bimno3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.6', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bimno3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.6', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.8', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.9', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.4', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'cageo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'cageo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
# No Matches {'material': ['perovskite', 'cahfo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cazro3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'start', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.0', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.2', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['spinel', 'coal2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['spinel', 'cocr2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['spinel', 'cocr2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'coga2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'coga2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'coga2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'coseo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'defect_location': 'final.1', 'material': ['spinel', 'cral2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['spinel', 'cral2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'crcr2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'crcr2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'crcr2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'start', 'material': ['spinel', 'cucr2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['spinel', 'cucr2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.3', 'material': ['spinel', 'cucr2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'start', 'material': ['spinel', 'cucr2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['spinel', 'cucr2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'cucr2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[37]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# ...
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'snbeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[32]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'zrbeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.5', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sicd2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sicd2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'simg2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'simg2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sizn2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sizn2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'vfe2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'vfe2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}

# %%
import matplotlib
import matplotlib.pyplot as plt
import pymongo
import gridfs
import bz2
import Vis
import time
from bson import ObjectId
from Classes_Pymatgen import *
from AddDB import *
from View_Structures import *
from Database_Tools import get_file
from Helpers import get_FERE_chemical_potential
from scipy.stats import gmean
import numpy as np
import Make_Dos
# %matplotlib inline
from material_helpers import *
try:
    client.close()
except:
    pass

(db,fs,client) = load_db()

# %%
match_criteria = {
    'pathway_count' : {'$exists' : True},
    'defect_type' : {'$exists' : False},
    'ts_type' : {'$exists' : False},
    'labels' : {'$all' ['from_zach']}
}

materials = [x['material'] for x in db.database.find(match_criteria).sort('material')]

print(len(materials))
print(materials)


def get_matches(temp_match_criteria):
    temp_matches = list(db.database.find(temp_match_criteria).sort('energy'))
    key = 'defect_type'
    if len(temp_matches) > 1:
        #         view_multiple(temp_matches)
        print('Multiple Matches {}'.format(temp_match_criteria))
        # [print('{} {}\n'.format(x[key], x['energy'])) for x in temp_matches if key in x]
        # [print('{} {}\n'.format(x[key], x['energy'])) for x in temp_matches if key in x]
        print()
        return temp_matches[0]
    elif len(temp_matches) == 0:
        print('No Matches {}'.format(temp_match_criteria))
        return None
    else:
        return temp_matches[0]


mat_dict = {}
ts_dict = {}

for material in materials:
    mat_dict[material[1]] = {}
    ts_dict[material[1]] = {}
    l = 7
    match_criteria = {
        'defect_location': {'$exists': False},
        'material': material,
        'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect'],
                   '$all' : ['from_zach']},
        'pathway_count': {'$exists': True},
        'poscar.structure.lattice.a': {'$gt': l},
        'ts_type': {'$exists': False},
        'energy' : {'$exists' : True},
        'misc_labels' : {'$nin' : ['kpts_div_2']},
    }
    base = get_matches(match_criteria)
    lb_criteria = {
        'material': material,
        'ts_type': 'pc',
        'index': -1,
        'misc_labels' : {'$nin' : ['kpts_div_2']},
        'energy' : {'$exists' : True},
        'kpoints.kpoints' : base['kpoints']['kpoints'],
        'labels': {'$nin': ['surface', 'interpolation', 'charged_defect'],
                   '$all' : ['from_zach']},
    }
    ub_criteria = {
        'material': material,
        'interpolation_direction': {'$exists': True},
        'index': -1,
        'misc_labels' : {'$nin' : ['kpts_div_2']},
        'kpoints.kpoints' : base['kpoints']['kpoints'],
        'labels': {'$nin': ['surface', 'charged_defect'],
                   '$all' : ['from_zach']},
    }

    match_criteria = {
        'defect_location': 'start',
        'material': material,
        'misc_labels' : {'$nin' : ['kpts_div_2']},
        'energy' : {'$exists' : True},
        'kpoints.kpoints' : base['kpoints']['kpoints'],
        'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect'],
                   '$all' : ['from_zach']},
    }
    start = get_matches(match_criteria)

    mat_dict[material[1]]['base'] = base
    mat_dict[material[1]]['start'] = start
    mat_dict[material[1]]['finals'] = []
    ts_dict[material[1]]['lb'] = []
    ts_dict[material[1]]['ub'] = []
    for i in range(int(base['pathway_count'][0])):
        match_criteria['defect_location'] = 'final.{}'.format(i)
        lb_criteria['index'] = '{}'.format(i)
        ub_criteria['index'] = '{}'.format(i)

        final = get_matches(match_criteria)
        lb = get_matches(lb_criteria)
        ub = list(db.database.find(ub_criteria))

        mat_dict[material[1]]['finals'].append(final)
        ts_dict[material[1]]['lb'].append(lb)
        ts_dict[material[1]]['ub'].append(ub)
# Out:
# 196
# [['h-barrier', 'al2o3'], ['h-barrier', 'al2o3'], ['spinel', 'alal2o4'], ['spinel', 'alv2o4'], ['spinel', 'alv2o4'], ['perovskite', 'bacoo3'], ['perovskite', 'bacoo3'], ['perovskite', 'bafeo3'], ['perovskite', 'bafeo3'], ['perovskite', 'bageo3'], ['perovskite', 'bageo3'], ['perovskite', 'bahfo3'], ['perovskite', 'bamn3po3'], ['perovskite', 'baseo3'], ['perovskite', 'basno3'], ['perovskite', 'basno3'], ['perovskite', 'batao3'], ['perovskite', 'bazro3'], ['perovskite', 'bazro3'], ['perovskite', 'bialo3'], ['perovskite', 'bicoo3'], ['perovskite', 'bicro3'], ['perovskite', 'bicuo3'], ['perovskite', 'bifeo3'], ['perovskite', 'bifeo3'], ['perovskite', '
ovskite', 'sralo3'], ['perovskite', 'srfeo3'], ['perovskite', 'srmn3po3'], ['perovskite', 'srsno3'], ['perovskite', 'yalo3'], ['perovskite', 'ygao3'], ['perovskite', 'scalo3'], ['perovskite', 'sncoo3'], ['perovskite', 'sncro3'], ['perovskite', 'snhfo3'], ['perovskite', 'snmno3'], ['perovskite', 'snnio3'], ['perovskite', 'snseo3'], ['perovskite', 'snsio3'], ['perovskite', 'sntao3'], ['perovskite', 'sntio3'], ['perovskit ...
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['h-barrier', 'al2o3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# No Matches {'defect_location': 'start', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.0', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.2', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.3', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['h-barrier', 'al2o3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# No Matches {'defect_location': 'start', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.0', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.2', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.3', 'material': ['h-barrier', 'al2o3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'al2o3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['spinel', 'alv2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['spinel', 'alv2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bacoo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bacoo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bageo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bamn3po3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bialo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bicoo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.5', 'material': ['perovskite', 'bicro3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicro3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bicuo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bicuo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[48]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'bifeo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bifeo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bifeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[34]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bigao3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[31]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.6', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bimno3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.6', 'material': ['perovskite', 'bimno3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'bimno3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.6', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.8', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.9', 'material': ['perovskite', 'binio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'binio3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[35]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bisbo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.4', 'material': ['perovskite', 'bivo3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'bivo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'defect_location': 'start', 'material': ['h-barrier', 'bn'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.0', 'material': ['h-barrier', 'bn'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'bn'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['h-barrier', 'bn'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['h-barrier', 'bn'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[2, 2, 2]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cafeo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[38]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'cageo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['perovskite', 'cageo3'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# No Matches {'material': ['perovskite', 'cahfo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'cavo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[28]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'cazro3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[29]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'start', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.0', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.1', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'defect_location': 'final.2', 'material': ['fluorite', 'ceo2'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['fluorite', 'ceo2'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[24]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['spinel', 'coal2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['spinel', 'cocr2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['spinel', 'cocr2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'coga2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'coga2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'coga2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# ...
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'znseo3'], 'ts_type': 'pc', 'index': '9', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[39]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'snbeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[32]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'tibeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[30]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'material': ['perovskite', 'yfeo3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'zrbeo3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.3', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '3', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '4', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.5', 'material': ['perovskite', 'vsio3'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '5', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '6', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '7', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['perovskite', 'vsio3'], 'ts_type': 'pc', 'index': '8', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sicd2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sicd2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'simg2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'simg2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[25]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sizn2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'sizn2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tico2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'tife2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'tife2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'vfe2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# No Matches {'material': ['spinel', 'znal2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[26]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': {'$exists': False}, 'material': ['spinel', 'vfe2o4'], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}, 'pathway_count': {'$exists': True}, 'poscar.structure.lattice.a': {'$gt': 7}, 'ts_type': {'$exists': False}, 'energy': {'$exists': True}, 'misc_labels': {'$nin': ['kpts_div_2']}}
#
# Multiple Matches {'defect_location': 'start', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# Multiple Matches {'defect_location': 'final.0', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '0', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.1', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '1', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}
# Multiple Matches {'defect_location': 'final.2', 'material': ['spinel', 'vfe2o4'], 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'ts', 'interpolation', 'charged_defect']}}
#
# No Matches {'material': ['spinel', 'vfe2o4'], 'ts_type': 'pc', 'index': '2', 'misc_labels': {'$nin': ['kpts_div_2']}, 'energy': {'$exists': True}, 'kpoints.kpoints': [[27]], 'labels': {'$nin': ['surface', 'interpolation', 'charged_defect']}}

# %%
mat_dict.keys()
# Out:
# D:\Users\RyanTrottier\AppData\Local\Continuum\miniconda3\envs\pymatgen\lib\site-packages\scipy\stats\stats.py:308: RuntimeWarning: invalid value encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))
# D:\Users\RyanTrottier\AppData\Local\Continuum\miniconda3\envs\pymatgen\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
